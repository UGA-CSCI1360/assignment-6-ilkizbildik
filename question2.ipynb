# %% [markdown]
# # CSCI 1360 - Assignment 6
# ## Question 2
#
# - Total points 50

# %% [markdown]
# ### Part A (Visual Analysis), 50 points
#
# Using [train.csv](train.csv), we will plot some charts that will reflect facts about survivals and casualties in the Titanic disaster. Split the dataset into two parts according to survival label and write code for the facts below using three plots:
#
# - For both survivals and casualties plot their age and ticket fare on one scatter plot. Show different marker for each split as shown in Figure 1.
#
# - Use separate histograms for survivals and casualties to show the count of passengers from each embarkation port. Similar to Figures 2 and 3 below.
#
# The dataset contains the following features:
#
# - PassengerId
# - Survived
# - Pclass (Ticket class)
# - Sex
# - Age
# - SibSp (No. of siblings / spouses aboard the Titanic)
# - Parch (No. of parents / children aboard the Titanic)
# - Fare (Passenger fare)
# - Embarked (Port of Embarkation. C = Cherbourg, Q = Queenstown, S = Southampton)
#
# **Instructions**
#
# * You are encouraged to create multiple cells in your notebook.
# * The only packages that are allowed in your solution are: `matplotlib`, `sklearn`, `pandas` and `numpy`.
# * An ideal solution would utilize your vectorized programming skills, such as slicing and fancy indexing.
#
# #### Grading Rubric
#
# - Correct scatter plot
# - Correct survivals histogram
# - Correct casualties histogram
# - Uses legend in the scatter plot
# - Uses labels in all plots

# %% [markdown]
# ### Figure 1
# ![image.png](attachment:image.png)
#
# ### Figure 2
# ![image-2.png](attachment:image-2.png)
#
# ### Figure 3
# ![image-3.png](attachment:image-3.png)

# %%
# You solution goes here
# you are encouraged to use multiple cells in the notebook
import numpy as np
import pandas as pd

df = pd.read_csv('train.csv')

df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female  30.0      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# 886        S
# 887        S
# 888        S
# 889        C
# 890        Q
#
# [891 rows x 9 columns]

# %%
np_arr = df.to_numpy()
survived=np.zeros(shape=(1,9))
casualty=np.zeros(shape=(1,9))
for i in range(1,np_arr.shape[0]):
    if int(np_arr[i,1])==1:
        survived=np.append(survived,[np_arr[i,:]], axis=0)
    elif int(np_arr[i,1])==0:
        casualty=np.append(casualty,[np_arr[i,:]], axis=0)

survived=survived[1:,:]
casualty=casualty[1:,:]

# %%
import matplotlib.pyplot as plt
x=list(float(survived[i,7]) for i in range(survived.shape[0]))
y=list(float(survived[i,4]) for i in range(survived.shape[0]))
x_1=list(float(casualty[i,7]) for i in range(casualty.shape[0]))
y_1=list(float(casualty[i,4]) for i in range(casualty.shape[0]))
plt.scatter(x,y, marker = "v", label="Survived")
plt.scatter(x_1,y_1, marker = "o",label="Casualties")
plt.xlabel("Fare")
plt.ylabel("Age")
plt.legend()

# %%
c=0
q=0
s=0
for i in range(survived.shape[0]):
    if survived[i,8]=="C":
        c+=1
    elif survived[i,8]=="Q":
        q+=1
    elif survived[i,8]=="S":
        s+=1              
y=[c,q,s]  
x=["Cherbourg", "Queenstown", "Southampton"]

# %%
plt.figure(figsize = (8, 5))
bar_colors = ['tab:blue', 'tab:orange', 'tab:green']
plt.bar(x,y,color=bar_colors,width = 0.15)
plt.ylabel("Survived")
plt.show()

# %%
c_1=0
q_1=0
s_1=0
for i in range(casualty.shape[0]):
    if casualty[i,8]=="C":
        c_1+=1
    elif casualty[i,8]=="Q":
        q_1+=1
    elif casualty[i,8]=="S":
        s_1+=1              
y=[c_1,q_1,s_1]  
x=["Cherbourg", "Queenstown", "Southampton"]

# %%
plt.figure(figsize = (8, 5))
bar_colors = ['tab:blue', 'tab:orange', 'tab:green']
plt.bar(x,y,color=bar_colors,width = 0.15)
plt.ylabel("Casualties")
plt.show()
